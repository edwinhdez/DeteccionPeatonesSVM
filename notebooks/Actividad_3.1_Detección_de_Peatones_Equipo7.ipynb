# %% [markdown]
# # Actividad 3.1 Detección de Peatones
# ### Equipo7

# %% [markdown]
# # Se cargan las bibliotecas necesarias

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import cv2
from skimage.feature import hog

from skimage.transform import resize # Para asegurar el tamaño de las imágenes

# %% [markdown]
# # Se importan los dos datasets
# ### https://www.kaggle.com/datasets/adityasinghz/pedestrian-detection-dataset?resource=download

# %%
import glob
pedestrian = glob.glob("data_svm/Positive/*.jpg")
no_pedestrian = glob.glob("data_svm/Negative/*.jpg")

# %%
len(pedestrian)
# Out:
# 3263

# %%
len(no_pedestrian)
# Out:
# 3266

# %% [markdown]
# # Se muestra una imagen con peatón

# %%
img_color = cv2.imread(pedestrian[889])
plt.imshow(img_color)

# %% [markdown]
# # Para fines de demostración se calcula el HOG de la imagen

# %%
img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap="gray")

# %%
img_gray = resize(img_gray, (100,100)) # para asegurar que todas las imágenes tengan el mismo tamaño
features,hog_img = hog(img_gray,
                       orientations = 8, # se reduce el número de orientaciones
                       pixels_per_cell = (16,16), # se mantienen celdas pequeñas para capturar los detalles
                       cells_per_block = (4,4), # se aumenta por tratar con imágenes más grandes
                       transform_sqrt = False,
                       visualize = True,
                       feature_vector = True)

# %%
features.shape
# Out:
# (1152,)

# %%
hog_img.shape
# Out:
# (100, 100)

# %%
plt.imshow(hog_img,cmap = 'gray')

# %% [markdown]
# # Se extraen las features del HOG para ambos tipos de datos

# %%
pedestrian_hog_accum = []

for i in pedestrian:
    img_color = cv2.imread(i) # se cambia mpimg a cv2 porque se trabaja con imágenes jpg
    img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
    img_gray = resize(img_gray, (100,100)) # para asegurar que todas las imágenes tengan el mismo tamaño
    
    pedestrian_hog_feature, pedestrian_hog_img = hog(img_gray,
                                           orientations = 8, # se reduce el número de orientaciones
                                           pixels_per_cell = (16,16), # se mantienen celdas pequeñas para capturar los detalles
                                           cells_per_block = (4,4), # se aumenta por tratar con imágenes más grandes
                                           transform_sqrt = False,
                                           visualize = True,
                                           feature_vector = True)
    
    pedestrian_hog_accum.append(pedestrian_hog_feature)

# %%
X_pedestrian = np.vstack(pedestrian_hog_accum).astype(np.float64)
y_pedestrian = np.ones(len(X_pedestrian))

# %%
X_pedestrian.shape
# Out:
# (3263, 1152)

# %%
y_pedestrian.shape
# Out:
# (3263,)

# %%
nopedestrian_hog_accum = []

for i in no_pedestrian:
    img_color = cv2.imread(i) # se cambia mpimg a cv2 porque se trabaja con imágenes jpg
    img_gray = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
    img_gray = resize(img_gray, (100,100)) # para asegurar que todas las imágenes tengan el mismo tamaño
    
    nopedestrian_hog_feature, nopedestrian_hog_img = hog(img_gray,
                                               orientations = 8, # se reduce el número de orientaciones
                                               pixels_per_cell = (16,16), # se mantienen celdas pequeñas para capturar los detalles
                                               cells_per_block = (4,4), # se aumenta por tratar con imágenes más grandes
                                               transform_sqrt = False,
                                               visualize = True,
                                               feature_vector = True)
    
    nopedestrian_hog_accum.append(nopedestrian_hog_feature)

# %%
X_nopedestrian = np.vstack(nopedestrian_hog_accum).astype(np.float64)
y_nopedestrian = np.zeros(len(X_nopedestrian))

# %%
X_nopedestrian.shape
# Out:
# (3266, 1152)

# %%
y_nopedestrian.shape
# Out:
# (3266,)

# %% [markdown]
# # Se combinan ambos tipos de datos para alimentar el SVM

# %%
X = np.vstack((X_pedestrian,X_nopedestrian))
X.shape
# Out:
# (6529, 1152)

# %%
y = np.hstack((y_pedestrian,y_nopedestrian))
y.shape
# Out:
# (6529,)

# %% [markdown]
# # Se generan los datos de entrenamiento y de prueba

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_train.shape
# Out:
# (4570, 1152)

# %%
X_test.shape
# Out:
# (1959, 1152)

# %% [markdown]
# # Se importa el Clasificador y se entrena

# %%
#from sklearn.svm import LinearSVC

#svc_model = LinearSVC()
#svc_model.fit(X_train, y_train)
from sklearn.svm import SVC

svc_model = SVC()
svc_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predict = svc_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test,y_predict)
sns.heatmap(cm, annot=True, fmt = "d")
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98       960
#          1.0       0.98      0.99      0.98       999
#
#     accuracy                           0.98      1959
#    macro avg       0.98      0.98      0.98      1959
# weighted avg       0.98      0.98      0.98      1959

# %% [markdown]
# # GridSearchCV

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=4)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.953 total time=  45.2s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.958 total time=  44.8s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.950 total time=  45.2s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.961 total time=  45.3s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.951 total time=  45.2s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.974 total time=  16.9s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.982 total time=  17.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.974 total time=  17.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.982 total time=  16.9s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.970 total time=  17.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.956 total time=  35.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.958 total time=  31.3s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.960 total time=  26.4s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.965 total time=  26.2s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.962 total time=  35.1s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.504 total time=  45.9s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.504 total time=  46.2s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.504 total time=  46.2s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.504 total time=  46.3s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.505 total time=  46.2s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  44.9s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  46.1s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  45.9s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  46.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.505 total time=  45.8s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.984 total time=  40.3s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.985 total time=  40.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=  39.9s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.979 total time=  40.2s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.974 total time=  40.1s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.986 total time=   7.5s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.987 total time=   7.4s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.981 total time=   7.4s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.984 total time=   7.5s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.977 total time=   7.4s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.970 total time=  14.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.982 total time=  14.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.972 total time=  14.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.980 total time=  14.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.970 total time=  14.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.956 total time=  34.5s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.960 total time=  35.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.958 total time=  35.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.965 total time=  35.2s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.962 total time=  35.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  46.6s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  46.3s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  46.4s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.504 total time=  46.6s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.505 total time=  46.2s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.985 total time=  40.3s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.987 total time=  40.2s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.970 total time=  40.5s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.979 total time=  40.1s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.975 total time=  40.3s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.988 total time=   5.7s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.989 total time=   5.6s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.981 total time=   5.5s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.988 total time=   5.7s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.979 total time=   5.5s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.984 total time=   6.2s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.982 total time=   6.1s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.975 total time=   6.3s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.981 total time=   6.4s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.973 total time=   6.3s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.972 total time=  13.4s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.981 total time=  13.8s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.972 total time=  13.7s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.980 total time=  13.7s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.970 total time=  13.7s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.956 total time=  34.2s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.960 total time=  34.6s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.958 total time=  34.8s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.965 total time=  34.7s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.962 total time=  34.8s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.985 total time=  40.3s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.987 total time=  40.3s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.970 total time=  40.3s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.979 total time=  40.1s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.975 total time=  40.2s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.988 total time=   5.7s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.988 total time=   5.8s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.981 total time=   5.7s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.985 total time=   5.8s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.980 total time=   5.5s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.978 total time=   4.2s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.976 total time=   4.2s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.973 total time=   4.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.979 total time=   4.2s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.965 total time=   4.2s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.980 total time=   6.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.982 total time=   6.2s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.975 total time=   6.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.980 total time=   6.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.970 total time=   6.2s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.972 total time=  13.6s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.981 total time=  13.9s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.972 total time=  13.9s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.980 total time=  13.7s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.970 total time=  13.9s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.985 total time=  40.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.987 total time=  40.6s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.970 total time=  40.4s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.979 total time=  40.5s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.975 total time=  40.5s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   5.7s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   5.9s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.981 total time=   5.4s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.985 total time=   5.7s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.980 total time=   5.5s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.982 total time=   4.2s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.981 total time=   4.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.976 total time=   3.9s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.980 total time=   3.9s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.969 total time=   3.9s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.977 total time=   4.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.977 total time=   4.2s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.972 total time=   4.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.979 total time=   4.2s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.963 total time=   4.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.980 total time=   5.9s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.982 total time=   6.2s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.975 total time=   6.1s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.980 total time=   6.2s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.970 total time=   6.2s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=4)

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma=0.1)

# %%
grid_predictions = grid.predict(X_test)

# %%
cm = confusion_matrix(y_test,grid_predictions)
sns.heatmap(cm, annot=True, fmt = "d")
# Out:
# <Axes: >

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98       960
#          1.0       0.98      0.99      0.98       999
#
#     accuracy                           0.98      1959
#    macro avg       0.98      0.98      0.98      1959
# weighted avg       0.98      0.98      0.98      1959

# %% [markdown]
# # Gracias por la atención
